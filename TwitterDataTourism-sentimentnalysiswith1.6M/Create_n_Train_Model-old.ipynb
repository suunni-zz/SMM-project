# %% [markdown]
# **Read the csv merged out of tweets collected for the 3 popular spots by bhagya**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# read in the data
#df = pd.read_csv('./output_got_LA_poi.csv',sep=';')
df = pd.read_csv('./Raw_data/full_NY_Oct-Dec2017.csv',sep=';')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20090 entries, 0 to 20089
# Data columns (total 10 columns):
# username     20090 non-null object
# date         20090 non-null object
# retweets     20090 non-null int64
# favorites    20090 non-null int64
# text         20087 non-null object
# geo          0 non-null float64
# mentions     9325 non-null object
# hashtags     8470 non-null object
# id           20090 non-null int64
# permalink    20090 non-null object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.5+ MB

# %%
df.head(100)
# Out:
#            username              date  retweets  favorites  \
# 0      YOHAN_artist  2017-10-31 05:29         0          0
# 1             hlo82  2017-10-31 05:29         0          0
# 2     _Rico_Marcelo  2017-10-31 05:29         0          0
# 3         KeefLouda  2017-10-31 05:29         0          0
# 4          BloomZee  2017-10-31 05:29         0          0
# 5      LauroBBorges  2017-10-31 05:29         0          0
# 6         AgriSarah  2017-10-31 05:29         0          0
# 7           samtori  2017-10-31 05:29         0          0
# 8    TheRealKevinho  2017-10-31 05:28         0          0
# 9       L0STINMY20s  2017-10-31 05:28         0          0
# 10   HollieGyarmati  2017-10-31 05:28         0          0
# 11        ReggieMCH  2017-10-31 05:28         0          0
# 12  CORONABARBERSHP  2017-10-31 05:28         0          0
# 13     DIABLOTRONYC  2017-10-31 05:28         0          0
# 14      JoeyBorrero  2017-10-31 05:28         0          0
# ...

# %%
df.sort_values(by=['favorites'], ascending=False)
# Out:
#               username              date  retweets  favorites  \
# 16081    ChrisisSingin  2017-12-30 01:44       215       3847
# 10877        eshygazit  2017-12-30 14:46       185        986
# 11692     MsLeaSalonga  2017-12-30 10:16        53        495
# 7706   kaitlynbristowe  2017-12-31 00:23         4        445
# 3497       SaraSampaio  2017-11-30 02:39        38        377
# 2732      JayMcGuiness  2017-11-30 03:51        96        300
# 10294          kkykr5h  2017-12-30 19:08         6        298
# 13184      daeguesnett  2017-12-30 06:45        89        292
# 15512      JakeSherman  2017-12-30 02:46        25        264
# 16554  clementineheaux  2017-12-30 00:46         7        202
# 9417        LC__Ashley  2017-12-30 21:29        48        189
# 13103    itsMorissette  2017-12-30 06:55        41        180
# 4197             TPAIN  2017-11-30 01:22       121        166
# 14307       LC__Ashley  2017-12-30 04:46        41        161
# ...

# %% [markdown]
# **getting the popular place info from the google api through code**

# %%
import urllib, json
import pprint

URL2 = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=los+angeles+point+of+interest&language=en&key=AIzaSyBIu7cZl56v5JgQw1mMXeMlm7k2DukNaWI"

googleResponse = urllib.urlopen(URL2)
jsonResponse = json.loads(googleResponse.read())
lst_data = jsonResponse['results']

# %% [markdown]
# **extracting the popular place list from json**

# %%
poi_list = []
for data in lst_data:
    poi_list.append(data['name'])
poi_list
# Out:
# [u'El Pueblo de Los Angeles Historical Monument',
#  u'Petersen Automotive Museum',
#  u'Hollywood Sign',
#  u'Korean Friendship Bell',
#  u'Bradbury Building',
#  u'Griffith Observatory',
#  u'The Getty',
#  u'Griffith Park',
#  u'Hollywood Walk of Fame',
#  u'Wat Thai of Los Angeles',
#  u'Venice Canals',
#  u'Urban Light',
#  u'Watts Towers State Historic Park',
#  u'LA Waterfront',
#  u'Los Angeles County Museum of Art',
#  u'Our Lady Queen of Angels Catholic Church',
#  u'Autry Museum of the American West',
#  u'Universal Studios Hollywood',
#  u'Statue "The Four Ladies of Hollywood"',
#  u'Hollywood Bowl']

# %% [markdown]
# ** Searching and tagging each tweet with popular_spot name found in text, adding column to the df with that popular_spot name**

# %%
def search_str(text):
    text = str(text)
    for poi in poi_list:
        if poi in text.decode('utf-8').strip():
            #print poi
            return poi
        
df['popular_spot'] = df['text'].apply(search_str)

# %%
df.to_csv("./Processed_data/temp.csv")

# %% [markdown]
# ** Extract Sentiment model saved and predict for each tweet**

# %%
from sklearn.externals import joblib
filename = './Models/sentiment_model.sav'
clf = joblib.load(filename)
filename = './Models/tfidf_vectorizer.sav'
tv = joblib.load(filename)

# %%
df.dropna(subset=['text'])
# Out:
#               username              date  retweets  favorites  \
# 0         YOHAN_artist  2017-10-31 05:29         0          0
# 1                hlo82  2017-10-31 05:29         0          0
# 2        _Rico_Marcelo  2017-10-31 05:29         0          0
# 3            KeefLouda  2017-10-31 05:29         0          0
# 4             BloomZee  2017-10-31 05:29         0          0
# 5         LauroBBorges  2017-10-31 05:29         0          0
# 6            AgriSarah  2017-10-31 05:29         0          0
# 7              samtori  2017-10-31 05:29         0          0
# 8       TheRealKevinho  2017-10-31 05:28         0          0
# 9          L0STINMY20s  2017-10-31 05:28         0          0
# 10      HollieGyarmati  2017-10-31 05:28         0          0
# 11           ReggieMCH  2017-10-31 05:28         0          0
# 12     CORONABARBERSHP  2017-10-31 05:28         0          0
# 13        DIABLOTRONYC  2017-10-31 05:28         0          0
# ...

# %%
pd.isnull(df['text']).to_csv("./Processed_data/null_text.csv")
df.dtypes
# Out:
# username         object
# date             object
# retweets          int64
# favorites         int64
# text             object
# geo             float64
# mentions         object
# hashtags         object
# id                int64
# permalink        object
# popular_spot     object
# dtype: object

# %%
df.text.astype(str)
# Out:
# 0        Copy of Free Now Single & Music Video - Lolee ...
# 1        Bebe- ozunapr Pal krissppy jejejjee New York… ...
# 2        Monday Blues Model: @ jessicatanir Follow : @ ...
# 3        Check out the single Lets Get It" by @ alloutk...
# 4        I'm at Foodtown in New York, NYhttps://www.swa...
# 5        Noivos em sessão de fotos. // # dumbo # brookl...
# 6        https://sarahjeanproduce.com/2017/10/30/get-fr...
# 7        Just posted a photo @Music Hall of Williamsbur...
# 8        Thankful for every living moment God has bless...
# 9        Fat /Soft/Standard/Thin Caps # nyc # graffiti ...
# 10       My holiday mantra finally pays me back in full...
# 11       Tomorrow Halloween Night Our 5th Annual Costum...
# 12       Have a safe & Happy Halloween!! DONT FORGET TO...
# 13       $29.99 + free shipping (USA only) Support your...
# 14       “I love scotch... scotchy scotch scotch.” - Ro...
# 15       Two New Yorkers fighting for your city. @TERMI...
# ...

# %%
tweet_tfidf = tv.transform(df['text'].astype(str))##.values.astype('U'))

# %%
tweet_pred = clf.predict(tweet_tfidf)
df["sent_pred"] = tweet_pred
df.shape
# Out:
# (20090, 12)

# %%
df.to_csv("./Processed_data/full_NY_Oct-Dec2017_sentiment_prediction.csv")

# %%
for index, row in df.head(10).iterrows():
    print((row['text'], row['sent_pred']))
    print("*"*50)
#df.head(10)
# Out:
# ('Copy of Free Now Single & Music Video - Lolee Pophttp://www.officialyohan.com/press1/2017/10/28/free-now-single-music-video-loleepop\xc2\xa0\xe2\x80\xa6', 4L)
# **************************************************
# ('Bebe- ozunapr Pal krissppy jejejjee New York\xe2\x80\xa6 https://www.instagram.com/p/Ba5DHScA78x/', 4L)
# **************************************************
# ('Monday Blues Model: @ jessicatanir Follow : @ _Rico_Marcelo # ricomarcelophotography\xe2\x80\xa6 https://www.instagram.com/p/Ba5DeVXgKHv/', 4L)
# **************************************************
# ('Check out the single Lets Get It" by @ alloutkable ft. @ KwyetStormNYC On soundcloud now at\xe2\x80\xa6 https://www.instagram.com/p/Ba5DdBuFCou/"', 4L)
# **************************************************
# ("I'm at Foodtown in New York, NYhttps://www.swarmapp.com/c/iiMINM1mTyr", 4L)
# **************************************************
# ...

# %%
df.head(10)
# Out:
#           username              date  retweets  favorites  \
# 0   CerritosAcura1  2017-12-29 05:29         0          0
# 1   Pay_Me_In_Gold  2017-12-29 05:29         0          0
# 2      laurieallee  2017-12-29 05:29         0          1
# 3  andersongouldjr  2017-12-29 05:29         0          0
# 4        madpoppin  2017-12-29 05:29         0          0
# 5  ShramptonTheCat  2017-12-29 05:28         0          1
# 6       CircaHouse  2017-12-29 05:28         0          0
# 7    joserkingdomx  2017-12-29 05:28         0          0
# 8  VincentLeeSmith  2017-12-29 05:28         0          0
# 9      SouthGateCA  2017-12-29 05:28         0          0
#
#                                                 text  geo         mentions  \
# 0  You need a little TLX in your life. # cerritos...  NaN        @Cerritos
# 1  First official music video Alone side ocsnaps ...  NaN                @
# 2  Raine's first time playing # tennis. @Orange G...  NaN          @Orange
# ...

# %% [markdown]
# **Extracting the total tweets and adding total favorites done per popular spots . We can even total the retweets happening for tweets per popular_spot**

# %%
testdf = df.groupby('popular_spot')
#df_extract = testdf.agg({'popular_spot':np.size, 'favorites':np.sum, 'retweets':np.sum, 'sent_pred':np.mean, 'mentions':np.sum, 'hashtags':np.sum })
#df_extract = testdf.agg({'popular_spot':np.size, 'favorites':np.sum, 'retweets':np.sum,'mentions':np.count_nonzero,'hashtags':np.count_nonzero, 'sent_pred':np.mean, 'follower_count':np.sum })
df_extract = testdf.agg({'popular_spot':np.size, 'favorites':np.sum, 'retweets':np.sum,'mentions':np.count_nonzero,'hashtags':np.count_nonzero, 'sent_pred':np.mean })

# %%
#testdf = df.groupby('popular_spot')
#print testdf['mentions'].str.get_dummies(sep=' ')

# %%
df_extract.sort_values(by=['favorites'], ascending=False)
# Out:
#                                               hashtags  sent_pred  retweets  \
# popular_spot
# Universal Studios Hollywood                        295   1.993220        30
# Hollywood Sign                                      82   3.756098         6
# The Broad                                           87   3.908046         3
# Griffith Observatory                                64   3.687500         4
# Los Angeles County Museum of Art                    43   1.581395         0
# Griffith Park                                       47   3.914894         2
# Petersen Automotive Museum                           7   3.428571         0
# Hollywood Bowl                                       3   2.666667         1
# California Science Center                           13   4.000000         1
# Venice Canals                                        9   4.000000         0
# Bradbury Building                                    5   4.000000         0
# ...

# %%
df_extract.to_csv("./Processed_data/LA_Dec2017_locationprediction.csv")
