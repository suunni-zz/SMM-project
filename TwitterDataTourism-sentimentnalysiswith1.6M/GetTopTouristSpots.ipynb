# %% [markdown]
# **Read the csv merged out of tweets collected for the 3 popular spots by bhagya**

# %%
# read in the LA city data from Oct 2017-Dec 2017

import pandas as pd
df = pd.read_csv('./Raw_data/full_LA_Oct-Dec2017.csv', sep=';', low_memory=False, usecols=['retweets','favorites','text','hashtags'])

# %%
# This step is to convert the text and hashtags column to string
# Then count the number of '#' in each cell in hashtags column to get the hashtag counts.

df['text'] = df.text.astype(str)
df['hashtags'] = df.hashtags.astype(str)
counts = []
for row in df['hashtags']:
    counts.append(row.strip().count('#'))
df['hashtagCounts'] = counts

# %% [markdown]
# **getting the popular place info from the google api through code**

# %%
# Extract points of interests from API Google search for LA City. Saving the list to lst_data

import urllib.request, json
import pprint

URL2 = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=los+angeles+point+of+interest&language=en&key=AIzaSyBIu7cZl56v5JgQw1mMXeMlm7k2DukNaWI"

googleResponse = urllib.request.urlopen(URL2)
jsonResponse = json.loads(googleResponse.read())
lst_data = jsonResponse['results']

# %% [markdown]
# **extracting the popular place list from json**

# %%
# In addition to getting the point of interest above, another code was written to extract the place names from
# tweets. That way we wanted to ensure we had all the places in the list. So in the below step, we are mergin the 
# list generated from the above step and the other list.

import pandas as pd

poi_list = []
for data in lst_data:
    poi_list.append(data['name'])
poi_list 
print(poi_list)

wholeListOfPoi=[]
df_poi = pd.read_csv('./pointOfIntersts.csv',header=None)
wholeListOfPoi = df_poi[0]

poi_list.extend(list(wholeListOfPoi))

print(poi_list)
# Out:
# ['El Pueblo de Los Angeles Historical Monument', 'Petersen Automotive Museum', 'Hollywood Sign', 'Korean Friendship Bell', 'Bradbury Building', 'Griffith Observatory', 'Wat Thai of Los Angeles', 'The Getty', 'Hollywood Walk of Fame', 'Griffith Park', 'Venice Canals', 'Urban Light', 'Watts Towers State Historic Park', 'LA Waterfront', 'Los Angeles County Museum of Art', 'Our Lady Queen of Angels Catholic Church', 'Universal Studios Hollywood', 'Autry Museum of the American West', 'Statue "The Four Ladies of Hollywood"', 'Hollywood Bowl']
# ['El Pueblo de Los Angeles Historical Monument', 'Petersen Automotive Museum', 'Hollywood Sign', 'Korean Friendship Bell', 'Bradbury Building', 'Griffith Observatory', 'Wat Thai of Los Angeles', 'The Getty', 'Hollywood Walk of Fame', 'Griffith Park', 'Venice Canals', 'Urban Light', 'Watts Towers State Historic Park', 'LA Waterfront', 'Los Angeles County Museum of Art', 'Our Lady Queen of Angels Catholic Church', 'Universal Studios Hollywood', 'Autry Museum of the American West', 'Statue "The Four Ladies of Hollywood"', 'Hollywood Bowl', 'santa monica', 'universal studios', 'studios hollywood', 'universal studios hollywood', 'west hollywood', 'universal city', 'st santa', 'st santa monica', 'international airport', 'venice beach', 'el monte', 'ave santa monica', 'ave santa', 'county museum', 'lacma county', 'lacma county museum', 'beverly hills', 'airport flylaxairport', 'hollywood walk', 'blvd santa monica', 'north hollywood', 'long beach', 'west covina']

# %%
# Once we have the place of interest, we are creating bigram and trigram in a dictionary with key as the popular
# tourist spot and values will be from bigram/trigram.

from nltk import everygrams
from nltk import word_tokenize
from nltk.corpus import stopwords
from collections import defaultdict

d = defaultdict(list)

stop_words = set(stopwords.words('english'))

for poi in poi_list:
    word_token = word_tokenize(poi.lower())
    word_stop = [token for token in word_token if token not in stop_words]
    grams = everygrams(word_stop, 2, 3)
    for i in grams:
        d[poi].append(i)

        
#print(d.items())

# %% [markdown]
# ** Searching and tagging each tweet with popular_spot name found in text, adding column to the df with that popular_spot name**

# %%
# Searching for the bigram, trigram in the tweet message and assigning it the tourist spot name

def search_str(text):
    for key, value in d.items():
        for v in value:
            v = " ".join(v)
            if v in text.lower().strip():
                return key

df['popular_spot'] = df['text'].apply(search_str)

#df.to_csv('bigramoutput.csv')
#df.head(100)

# %% [markdown]
# **Extracting the total tweets and adding total favorites done per popular spots . We can even total the retweets happening for tweets per popular_spot**

# %%
# in the below process, we are creating our sentiment model and saving it for reuse.

from sklearn.externals import joblib
filename = 'sentiment_model3.0.sav'
clf = joblib.load(filename)
filename = 'tfidf_vectorizer3.0.sav'
tv = joblib.load(filename)

# %%
# This step is to actually create a prediction score for each tweet using the model. The dataframe is passed to next
# step to get the aggregate sums. Also is saved to a file for review.

tweet_tfidf = tv.transform(df['text'].astype(str))
tweet_pred = clf.predict(tweet_tfidf)
df["sent_pred"] = tweet_pred
df.to_csv("DataNew.csv")

# %%
# Group the dataframe by popular spot and get the aggregate counts for favorites, retweets, hashtagcounts, and mean for the prediction

import numpy as np
testdf = df.groupby('popular_spot')
df_extract = testdf.agg({'favorites':np.sum, 'retweets':np.sum, 'hashtagCounts':np.sum, 'sent_pred': np.mean})
df_extract.sort_values(by=['favorites'], ascending=False)
# Out:
#                                               favorites  retweets  \
# popular_spot
# El Pueblo de Los Angeles Historical Monument     103105     17505
# santa monica                                      16677      3623
# beverly hills                                      3032       545
# Universal Studios Hollywood                        1968       416
# Hollywood Bowl                                     1492       149
# west hollywood                                     1459       236
# venice beach                                       1169       107
# Hollywood Sign                                      588        95
# Hollywood Walk of Fame                              569        80
# north hollywood                                     520       100
# universal city                                      292        36
# Griffith Observatory                                159        22
# long beach                                          141        15
# Griffith Park                                       132        16
# west covina                                         106        27
# el monte                                             64        23
# Petersen Automotive Museum                           29         2
# Urban Light                                          22         3
# Venice Canals                                        15         0
# Watts Towers State Historic Park                     14         2
# Bradbury Building                                    13         0
# Our Lady Queen of Angels Catholic Church             10         0
# Autry Museum of the American West                     4         0
# international airport                                 4         0
# ave santa monica                                      2         0
# LA Waterfront                                         1         0
# blvd santa monica                                     0         0
# st santa                                              0         0
# Korean Friendship Bell                                0         0
# Wat Thai of Los Angeles                               0         0
#
#                                               hashtagCounts  sent_pred
# popular_spot
# El Pueblo de Los Angeles Historical Monument          25916   3.890009
# santa monica                                           2627   3.868899
# beverly hills                                          1723   3.851136
# Universal Studios Hollywood                             685   3.946269
# Hollywood Bowl                                          523   3.921909
# west hollywood                                          970   3.958549
# venice beach                                           1018   3.881818
# Hollywood Sign                                          385   3.926316
# Hollywood Walk of Fame                                  592   3.989783
# north hollywood                                         404   3.679767
# universal city                                          118   3.980296
# Griffith Observatory                                    246   3.841584
# long beach                                              106   2.984615
# Griffith Park                                           282   3.913793
# west covina                                             117   3.855422
# el monte                                                 74   3.000000
# Petersen Automotive Museum                               64   4.000000
# Urban Light                                              53   3.812500
# Venice Canals                                            58   4.000000
# Watts Towers State Historic Park                         11   4.000000
# Bradbury Building                                        15   4.000000
# Our Lady Queen of Angels Catholic Church                 41   3.714286
# Autry Museum of the American West                         9   4.000000
# international airport                                    24   4.000000
# ave santa monica                                          0   4.000000
# LA Waterfront                                             0   4.000000
# blvd santa monica                                         0   4.000000
# st santa                                                  4   4.000000
# Korean Friendship Bell                                    5   4.000000
# Wat Thai of Los Angeles                                   0   4.000000

# %%
import numpy as np
import pandas
import csv
from sklearn import preprocessing

testdf = df.groupby('popular_spot')
df_extract = testdf.agg({'popular_spot':np.size, 'favorites':np.sum, 'retweets':np.sum, 'hashtagCounts':np.size, 'sent_pred':np.sum})
df_extract.sort_values(by=['favorites'], ascending=False)


x = df_extract.ix[:,[1,2,3,4]].values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)


df1 = pandas.DataFrame(x_scaled)
df1.index = df_extract.index
df1['mean'] = df1.mean(axis=1)
df2 = df1.sort_values(by=['mean'], ascending=False)
print(df1.sort_values(by=['mean'], ascending=False))

df2.iloc[0:20,4].to_csv('FinalReport.csv')
# Out:
#                                                      0         1         2  \
# popular_spot
# El Pueblo de Los Angeles Historical Monument  1.000000  1.000000  1.000000
# santa monica                                  0.161748  0.206969  0.130273
# beverly hills                                 0.029407  0.031134  0.063539
# west hollywood                                0.014151  0.013482  0.053338
# Universal Studios Hollywood                   0.019087  0.023765  0.041141
# venice beach                                  0.011338  0.006113  0.027007
# Hollywood Walk of Fame                        0.005519  0.004570  0.024027
# north hollywood                               0.005043  0.005713  0.021077
# Hollywood Bowl                                0.014471  0.008512  0.014133
# Hollywood Sign                                0.005703  0.005427  0.011645
# el monte                                      0.000621  0.001314  0.017421
# universal city                                0.002832  0.002057  0.012444
# Griffith Observatory                          0.001542  0.001257  0.009279
# west covina                                   0.001028  0.001542  0.007620
# Griffith Park                                 0.001280  0.000914  0.007097
# long beach                                    0.001368  0.000857  0.007958
# Urban Light                                   0.000213  0.000171  0.001936
# Petersen Automotive Museum                    0.000281  0.000114  0.001475
# Venice Canals                                 0.000145  0.000000  0.001260
# Our Lady Queen of Angels Catholic Church      0.000097  0.000000  0.001260
# Watts Towers State Historic Park              0.000136  0.000114  0.001014
# Bradbury Building                             0.000126  0.000000  0.000553
# Autry Museum of the American West             0.000039  0.000000  0.000215
# international airport                         0.000039  0.000000  0.000123
# Wat Thai of Los Angeles                       0.000000  0.000000  0.000031
# ave santa monica                              0.000019  0.000000  0.000000
# LA Waterfront                                 0.000010  0.000000  0.000000
# blvd santa monica                             0.000000  0.000000  0.000000
# st santa                                      0.000000  0.000000  0.000000
# Korean Friendship Bell                        0.000000  0.000000  0.000000
#
#                                                      3      mean
# popular_spot
# El Pueblo de Los Angeles Historical Monument  1.000000  1.000000
# santa monica                                  0.129565  0.157139
# beverly hills                                 0.062903  0.046746
# west hollywood                                0.054278  0.033812
# Universal Studios Hollywood                   0.041735  0.031432
# venice beach                                  0.026949  0.017852
# Hollywood Walk of Fame                        0.024643  0.014690
# north hollywood                               0.019936  0.012942
# Hollywood Bowl                                0.014249  0.012841
# Hollywood Sign                                0.011753  0.008632
# el monte                                      0.013427  0.008196
# universal city                                0.012732  0.007516
# Griffith Observatory                          0.009162  0.005310
# west covina                                   0.007551  0.004435
# Griffith Park                                 0.007140  0.004108
# long beach                                    0.006098  0.004070
# Urban Light                                   0.001896  0.001054
# Petersen Automotive Museum                    0.001516  0.000847
# Venice Canals                                 0.001295  0.000675
# Our Lady Queen of Angels Catholic Church      0.001201  0.000639
# Watts Towers State Historic Park              0.001043  0.000577
# Bradbury Building                             0.000569  0.000312
# Autry Museum of the American West             0.000221  0.000119
# international airport                         0.000126  0.000072
# Wat Thai of Los Angeles                       0.000032  0.000016
# ave santa monica                              0.000000  0.000005
# LA Waterfront                                 0.000000  0.000002
# blvd santa monica                             0.000000  0.000000
# st santa                                      0.000000  0.000000
# Korean Friendship Bell                        0.000000  0.000000
# C:\BD\Anaconda3\lib\site-packages\ipykernel\__main__.py:11: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# C:\BD\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, _DataConversionWarning)
